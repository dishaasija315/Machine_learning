# %%
#list creation
countries = ["India",'Australia','usa']
print(countries)

#accessing list elements
print("value at index 0")

hybridlists=["my name is ", "disha", 3, "semester"]
print(hybridlists)

for item in hybridlists:
              print(item)
# Out:
# ['India', 'Australia', 'usa']
# value at index 0
# ['my name is ', 'disha', 3, 'semester']
# my name is
# disha
# 3
# semester

# %%
countries = ["india","australia", "usa"]
for index, country in enumerate(countries):
  place=str(index)
  print ("index"+ place+", value:"+country)
  index = countries.index("india")
  print ("\n index of india is:" , index)
# Out:
# index0, value:india
#
#  index of india is: 0
# index1, value:australia
#
#  index of india is: 0
# index2, value:usa
#
#  index of india is: 0

# %%
del countries [-1]
print(countries)
# Out:
# ['india', 'australia']

# %%
#normal for loop
l=[1,2,3,4,4]
for i in l :
  print (i%2)
# Out:
# 1
# 0
# 1
# 0
# 0

# %%
l=[2,4,6,8,10,114]
[i**2 for i in l if i**2>50]
# Out:
# [64, 100, 12996]

# %%
dict ={"sedan":1500,"suv":2000,"pickup":2500}
d=[i.lower() for i in dict if dict[i]<5000]
print(d)
# Out:
# ['sedan', 'suv', 'pickup']

# %%
l=[1,2,3,4,5,6,7,8,9]
l2=["high" if i>5 else "low" for i in l]
print(l2)
# Out:
# ['low', 'low', 'low', 'low', 'low', 'high', 'high', 'high', 'high']

# %%
l=[1,2,3,4,5,6,7,8,9]
l2=[1 if i>5 else 0 for i in l]
print(l2)
# Out:
# [0, 0, 0, 0, 0, 1, 1, 1, 1]

# %%
l=[1,2,3,4,5,6,7,8,9]
l2=[27*x for x in range (1,21) if x**2<=10]
print(l2)
# Out:
# [27, 54, 81]

# %%
[ x for x in range(51) if x%2==0 and x%5==0]
# Out:
# [0, 10, 20, 30, 40, 50]

# %%
string="i love this csit department"
j=[]
j = [i for i in string if i in ["a","e","i","o","u"]]
print(j)
# Out:
# ['i', 'o', 'e', 'i', 'i', 'e', 'a', 'e']

# %%
l=[1,2,3,4,5,6,7,8,9]
l2=[l.pop(l.index(i)) for i in l if i%2 !=0]
print(l2)
# Out:
# [1, 3, 5, 7, 9]

# %%
sentence= "in 1984 there were 13 instanced of a prot"
words = sentence.split()
result =[ number for number in words if not number.isalpha()]
print(result)
# Out:
# ['1984', '13']

# %%
list1 = [1, 2, 3, 4, 5]
list2 = [3, 4, 5, 6, 7]

common = [x for x in list1 if x in list2]

print(common)
# Out:
# [3, 4, 5]
